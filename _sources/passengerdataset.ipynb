# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df_passenger = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv')
df_passenger.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
    # find the end of this pattern
        end_ix = i + n_steps

    # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
    # gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    X.append(seq_x)
    y.append(seq_y)
    return X, y

# %%
df_passenger.shape
# Out:
# (144, 2)

# %%
new= df_passenger['Passengers'].values

# %%
new
# Out:
# array([112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115,
#        126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140, 145, 150,
#        178, 163, 172, 178, 199, 199, 184, 162, 146, 166, 171, 180, 193,
#        181, 183, 218, 230, 242, 209, 191, 172, 194, 196, 196, 236, 235,
#        229, 243, 264, 272, 237, 211, 180, 201, 204, 188, 235, 227, 234,
#        264, 302, 293, 259, 229, 203, 229, 242, 233, 267, 269, 270, 315,
#        364, 347, 312, 274, 237, 278, 284, 277, 317, 313, 318, 374, 413,
#        405, 355, 306, 271, 306, 315, 301, 356, 348, 355, 422, 465, 467,
#        404, 347, 305, 336, 340, 318, 362, 348, 363, 435, 491, 505, 404,
#        359, 310, 337, 360, 342, 406, 396, 420, 472, 548, 559, 463, 407,
#        362, 405, 417, 391, 419, 461, 472, 535, 622, 606, 508, 461, 390,
#        432])

# %%
# transform univariate time series to supervised learning problem
from numpy import array
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
    # find the end of this pattern
        end_ix = i + n_steps
    # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
    # gather input and output parts of the pattern
        # print(i, end_ix)
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

X, y = split_sequence(new, 3)

# %%
df_X = pd.DataFrame(X, columns=['Xt-2', 'Xt-1', 'output'])
df_y = pd.DataFrame(y, columns=['y'])

# %%
df_X.head()
# Out:
#    Xt-2  Xt-1  output
# 0   112   118     132
# 1   118   132     129
# 2   132   129     121
# 3   129   121     135
# 4   121   135     148

# %%
dataNormalisasi = ['Xt-2', 'Xt-1', 'output']
FrameNormalisasi = df_X[dataNormalisasi]
FrameNormalisasi
# Out:
#      Xt-2  Xt-1  output
# 0     112   118     132
# 1     118   132     129
# 2     132   129     121
# 3     129   121     135
# 4     121   135     148
# ..    ...   ...     ...
# 136   472   535     622
# 137   535   622     606
# 138   622   606     508
# 139   606   508     461
# 140   508   461     390
#
# [141 rows x 3 columns]

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(FrameNormalisasi)
# Out:
# MinMaxScaler()

# %%
hasilNormalisasi = scaler.transform(FrameNormalisasi)

# %%
hasilNormalisasi = pd.DataFrame(hasilNormalisasi,columns = dataNormalisasi)
hasilNormalisasi
# Out:
#          Xt-2      Xt-1    output
# 0    0.015444  0.027027  0.054054
# 1    0.027027  0.054054  0.048263
# 2    0.054054  0.048263  0.032819
# 3    0.048263  0.032819  0.059846
# 4    0.032819  0.059846  0.084942
# ..        ...       ...       ...
# 136  0.710425  0.832046  1.000000
# 137  0.832046  1.000000  0.969112
# 138  1.000000  0.969112  0.779923
# 139  0.969112  0.779923  0.689189
# 140  0.779923  0.689189  0.552124
#
# [141 rows x 3 columns]

# %%
percent_amount_of_test_data = 0.3

# %%
X1 = hasilNormalisasi.iloc[:,1:3].values
Y1 = hasilNormalisasi.iloc[:,0].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size = percent_amount_of_test_data, random_state=0)

# %%
X_train.shape
# Out:
# (98, 2)

# %%
Y1
# Out:
# array([0.01544402, 0.02702703, 0.05405405, 0.04826255, 0.03281853,
#        0.05984556, 0.08494208, 0.08494208, 0.06177606, 0.02895753,
#        0.        , 0.02702703, 0.02123552, 0.04247104, 0.07142857,
#        0.05984556, 0.04054054, 0.08687259, 0.12741313, 0.12741313,
#        0.1042471 , 0.05598456, 0.01930502, 0.06949807, 0.07915058,
#        0.08880309, 0.14285714, 0.11389961, 0.13127413, 0.14285714,
#        0.18339768, 0.18339768, 0.15444015, 0.11196911, 0.08108108,
#        0.11969112, 0.12934363, 0.14671815, 0.17181467, 0.14864865,
#        0.15250965, 0.22007722, 0.24324324, 0.26640927, 0.2027027 ,
#        0.16795367, 0.13127413, 0.17374517, 0.17760618, 0.17760618,
#        0.25482625, 0.25289575, 0.24131274, 0.26833977, 0.30888031,
#        0.32432432, 0.25675676, 0.20656371, 0.14671815, 0.18725869,
#        0.19305019, 0.16216216, 0.25289575, 0.23745174, 0.25096525,
#        0.30888031, 0.38223938, 0.36486486, 0.2992278 , 0.24131274,
# ...
