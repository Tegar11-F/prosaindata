# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snscrape in /usr/local/lib/python3.8/dist-packages (0.5.0.20230113)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
query = "(cakimin) until:2023-02-20 since:2022-01-01"
tweets = []
limit = 500

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
  if len(tweets)==limit:
    break
  else:
    tweets.append([tweet.date, tweet.user.username, tweet.content, tweet.user.location])

df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet', 'lokasi'])
print(df)
# Out:
# <ipython-input-17-df37cef05596>:9: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.user.username, tweet.content, tweet.user.location])
#                          Date             User  \
# 0   2023-02-19 18:29:44+00:00  ahmadhellishfau
# 1   2023-02-19 15:29:32+00:00  ahmadhellishfau
# 2   2023-02-19 14:29:40+00:00  ahmadhellishfau
# 3   2023-02-19 14:23:59+00:00      LamonganPkb
# 4   2023-02-19 12:51:39+00:00  alimahfud200670
# ..                        ...              ...
# 495 2023-01-30 01:00:01+00:00      gerindramjk
# 496 2023-01-30 00:50:59+00:00    fauzanfuadiFF
# 497 2023-01-29 23:53:23+00:00       sutiknopkb
# 498 2023-01-29 15:28:06+00:00        pkbJember
# 499 2023-01-29 15:13:01+00:00        pkbJember
#
#                                                  Tweet  \
# 0    #JokowiCakImin #JoinKepri2019 #NasionalisRelig...
# 1    #JokowiCakImin #JoinKepri2019 #NasionalisRelig...
# 2    #JokowiCakImin #JoinKepri2019 #NasionalisRelig...
# 3    Seberapa Kuat Elektabilitas PKB Partai Pengusu...
# 4    @dpcpkbjaksel @cakimin @DPP_PKB @Alam_PKBJakse...
# ..                                                 ...
# 495  Selamat pagi... semangat bekerja\n"Kalau saya ...
# 496  1 Abad NU\n\n@cakiminow \n\n#satuabadnu \n#1ab...
# 497  Tetap solid sampai menjadi pemenang !!\n\n#cak...
# 498  Dalam rangka menyambut satu abad Nahdlatul Ula...
# 499  Sarasehan Nasional\nSatu Abad NU\nSatu abad ke...
#
#                            lokasi
# 0
# 1
# 2
# 3
# 4            Kertosono, Indonesia
# ..                            ...
# 495  Puri Majapahit B3, Mojokerto
# 496
# 497
# 498            Jember, Jawa Timur
# 499            Jember, Jawa Timur
#
# [500 rows x 4 columns]

# %%
df.to_csv('crawllingtwet.csv')
