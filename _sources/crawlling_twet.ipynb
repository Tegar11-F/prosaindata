# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# query = "(cakimin) until:2023-02-20 since:2022-01-01"
# tweets = []
# limit = 500

# for tweet in sntwitter.TwitterSearchScraper(query).get_items():
#   if len(tweets)==limit:
#     break
#   else:
#     tweets.append([tweet.date, tweet.user.username, tweet.content, tweet.user.location])

# df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet', 'lokasi'])
# print(df)

# %%
# df.to_csv('crawllingtwet.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Tegar11-F/Data-Set/main/crawllingtwet%20(2).csv')
# df = df.drop(['Unnamed: 0.1'], axis=1)
df.head()
# Out:
#    Unnamed: 0                       Date             User  \
# 0           0  2023-02-19 18:29:44+00:00  ahmadhellishfau
# 1           1  2023-02-19 15:29:32+00:00  ahmadhellishfau
# 2           2  2023-02-19 14:29:40+00:00  ahmadhellishfau
# 3           3  2023-02-19 14:23:59+00:00      LamonganPkb
# 4           4  2023-02-19 12:51:39+00:00  alimahfud200670
#
#                                                Tweet  \
# 0  #JokowiCakImin #JoinKepri2019 #NasionalisRelig...
# 1  #JokowiCakImin #JoinKepri2019 #NasionalisRelig...
# 2  #JokowiCakImin #JoinKepri2019 #NasionalisRelig...
# 3  Seberapa Kuat Elektabilitas PKB Partai Pengusu...
# 4  @dpcpkbjaksel @cakimin @DPP_PKB @Alam_PKBJakse...
#
#                           lokasi
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4  جدة, المملكة العربية السعودية
